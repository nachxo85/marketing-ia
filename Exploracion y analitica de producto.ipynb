# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # 1. Load Data

# %%
df = pd.read_csv('Datoscompletos3.csv',sep=";",parse_dates=[10],dayfirst=True)

# %%
df.shape
# Out:
# (7902, 13)

# %%
df.head()
# Out:
#    id_reserva Día de semana de fecha_venta  Hora de turno    canal cpais_id  \
# 0           1                    miércoles             20  canal_1   Pais_1
# 1           2                    miércoles             20  canal_1   Pais_1
# 2           3                    miércoles             20  canal_2   Pais_1
# 3           4                    miércoles             20  canal_2   Pais_1
# 4           5                    miércoles             20  canal_2   Pais_1
#
#    descuento genero    provincia    tarifa    tipo_servicio fecha_venta  \
# 0          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
# 1          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
# 2          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
# 3          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
# 4          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
#
#      familia  precio
# 0  familia_1      35
# 1  familia_1      35
# 2  familia_1      35
# 3  familia_1      35
# 4  familia_1      35

# %% [markdown]
# # 2. Product Analytics

# %% [markdown]
# #### - Quantity Distribution

# %%
(df.groupby(['tipo_servicio'])['tipo_servicio'].count()).head()
# Out:
# tipo_servicio
# tipo_servicio_1    4029
# tipo_servicio_2       2
# tipo_servicio_3    3850
# tipo_servicio_4      21
# Name: tipo_servicio, dtype: int64

# %%
df.groupby('tipo_servicio').size().plot(kind='bar')

# %%
pd.DataFrame(df['tipo_servicio'].describe())
# Out:
#           tipo_servicio
# count              7902
# unique                4
# top     tipo_servicio_1
# freq               4029

# %%
(df.groupby(['precio'])['precio'].count()).head()
# Out:
# precio
# 35    7868
# 40      11
# 43      21
# 60       2
# Name: precio, dtype: int64

# %%
df.groupby('precio').size().plot(kind='bar')

# %%
(df.groupby(['familia'])['familia'].count()).head()
# Out:
# familia
# familia_1    7788
# familia_2      46
# familia_3      67
# familia_4       1
# Name: familia, dtype: int64

# %%
df.groupby('familia').size().plot(kind='bar')

# %%
(df.groupby(['provincia'])['provincia'].count()).head()
# Out:
# provincia
# PROVINCIA_1    7105
# PROVINCIA_2     362
# PROVINCIA_3      43
# PROVINCIA_4     392
# Name: provincia, dtype: int64

# %%
df.groupby('provincia').size().plot(kind='bar')

# %%
(df.groupby(['genero'])['genero'].count()).head()
# Out:
# genero
# H    7524
# M     378
# Name: genero, dtype: int64

# %%
df.groupby('genero').size().plot(kind='bar')

# %%
(df.groupby(['descuento'])['descuento'].count()).head()
# Out:
# descuento
# 0     5026
# 20    2463
# 25     413
# Name: descuento, dtype: int64

# %%
df.groupby('descuento').size().plot(kind='bar')

# %%
(df.groupby(['cpais_id'])['cpais_id'].count()).head()
# Out:
# cpais_id
# Pais_1    7880
# Pais_2       2
# Pais_3      16
# Pais_4       1
# Pais_5       3
# Name: cpais_id, dtype: int64

# %%
df.groupby('cpais_id').size().plot(kind='bar')

# %%
(df.groupby(['canal'])['canal'].count()).head()
# Out:
# canal
# canal_1    2520
# canal_2    1271
# canal_3    4111
# Name: canal, dtype: int64

# %%
df.groupby('canal').size().plot(kind='bar')

# %%
(df.groupby(['Hora de turno'])['Hora de turno'].count()).head()
# Out:
# Hora de turno
# 10     509
# 12    1499
# 14     488
# 16    1223
# 18    2278
# Name: Hora de turno, dtype: int64

# %%
df.groupby('Hora de turno').size().plot(kind='bar')

# %%
(df.groupby(['Día de semana de fecha_venta'])['Día de semana de fecha_venta'].count()).head()
# Out:
# Día de semana de fecha_venta
# domingo       913
# jueves       1168
# lunes        1174
# martes       1167
# miércoles    1161
# Name: Día de semana de fecha_venta, dtype: int64

# %%
df.groupby('Día de semana de fecha_venta').size().plot(kind='bar')

# %% [markdown]
# #### - Time-series Number of Orders

# %%
ventas_diarias_df = df.set_index('fecha_venta')['id_reserva'].resample('M').nunique()

# %%
ventas_mensuales_df2 = df.set_index('fecha_venta')['id_reserva'].resample('M').nunique().reset_index(name='total')
ventas_mensuales_df2.sort_values(['total'], ascending=False).head()
# Out:
#    fecha_venta  total
# 36  2020-01-31    482
# 37  2020-02-29    452
# 58  2021-11-30    450
# 57  2021-10-31    447
# 56  2021-09-30    441

# %%
ax = pd.DataFrame(ventas_diarias_df.values).plot(
    grid=True,
    figsize=(10,7),
    legend=False
)

ax.set_xlabel('fecha')
ax.set_ylabel('numero de ventas')
ax.set_title('Total numero de ventas a lo largo del tiempo')

plt.xticks(
    range(len(ventas_diarias_df.index)), 
    [x.strftime('%m.%Y') for x in ventas_diarias_df.index], 
    rotation=45
)

plt.show()

# %%
#eliminamos las fechas que tienen escasos datos
extracto_ventas = ventas_mensuales_df2.loc[ ventas_mensuales_df2['fecha_venta'] >= '2018-12-31',:]

# %%
extracto_ventas.shape
# Out:
# (38, 2)

# %% [markdown]
# #### - Time-series Revenue

# %%
precio_final_df=df
precio_final_df['precio_final'] = precio_final_df['precio'] * (1+(precio_final_df['descuento']/100))

# %%
precio_final_df.head()
# Out:
#    id_reserva Día de semana de fecha_venta  Hora de turno    canal cpais_id  \
# 0           1                    miércoles             20  canal_1   Pais_1
# 1           2                    miércoles             20  canal_1   Pais_1
# 2           3                    miércoles             20  canal_2   Pais_1
# 3           4                    miércoles             20  canal_2   Pais_1
# 4           5                    miércoles             20  canal_2   Pais_1
#
#    descuento genero    provincia    tarifa    tipo_servicio fecha_venta  \
# 0          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
# 1          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
# 2          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
# 3          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
# 4          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
#
#      familia  precio  precio_final
# 0  familia_1      35          35.0
# 1  familia_1      35          35.0
# 2  familia_1      35          35.0
# 3  familia_1      35          35.0
# 4  familia_1      35          35.0

# %%
facturacion_mensual_df = df.set_index('fecha_venta')['precio_final'].resample('M').sum()

# %%
facturacion_mensual_df
# Out:
# fecha_venta
# 2017-01-31      436.45
# 2017-02-28      232.20
# 2017-03-31      180.60
# 2017-04-30       86.00
# 2017-05-31       51.60
#                 ...
# 2021-09-30    16595.00
# 2021-10-31    17078.25
# 2021-11-30    17017.00
# 2021-12-31     5908.00
# 2022-01-31      448.00
# Freq: M, Name: precio_final, Length: 61, dtype: float64

# %%
ax = pd.DataFrame(facturacion_mensual_df.values).plot(
    grid=True,
    figsize=(10,7),
    legend=False
)

ax.set_xlabel('fecha')
ax.set_ylabel('ventas')
ax.set_title('Ventas totales a lo largo del tiempo')

ax.set_ylim([0, max(facturacion_mensual_df.values)+1000])

plt.xticks(
    range(len(facturacion_mensual_df.index)), 
    [x.strftime('%m.%Y') for x in facturacion_mensual_df.index], 
    rotation=45
)

plt.show()

# %%
precio_final_df.head()
# Out:
#    id_reserva Día de semana de fecha_venta  Hora de turno    canal cpais_id  \
# 0           1                    miércoles             20  canal_1   Pais_1
# 1           2                    miércoles             20  canal_1   Pais_1
# 2           3                    miércoles             20  canal_2   Pais_1
# 3           4                    miércoles             20  canal_2   Pais_1
# 4           5                    miércoles             20  canal_2   Pais_1
#
#    descuento genero    provincia    tarifa    tipo_servicio fecha_venta  \
# 0          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
# 1          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
# 2          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
# 3          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
# 4          0      H  PROVINCIA_1  tarifa_1  tipo_servicio_1  2020-01-01
#
#      familia  precio  precio_final
# 0  familia_1      35          35.0
# 1  familia_1      35          35.0
# 2  familia_1      35          35.0
# 3  familia_1      35          35.0
# 4  familia_1      35          35.0

# %%
facturacion_mensual_por_producto_df = df.set_index('fecha_venta').groupby(['tipo_servicio'])['precio_final'].resample('M').sum().reset_index(name='total')

with pd.option_context("display.max_rows", None):
    display(facturacion_mensual_por_producto_df)
# Out:
#       tipo_servicio fecha_venta     total
# 0   tipo_servicio_1  2019-10-31   1610.00
# 1   tipo_servicio_1  2019-11-30   6475.00
# 2   tipo_servicio_1  2019-12-31   8295.00
# 3   tipo_servicio_1  2020-01-31  11235.00
# 4   tipo_servicio_1  2020-02-29   9633.75
# 5   tipo_servicio_1  2020-03-31   2555.00
# 6   tipo_servicio_1  2020-04-30      0.00
# 7   tipo_servicio_1  2020-05-31      0.00
# 8   tipo_servicio_1  2020-06-30   9065.00
# 9   tipo_servicio_1  2020-07-31   7525.00
# 10  tipo_servicio_1  2020-08-31   6972.00
# 11  tipo_servicio_1  2020-09-30   6405.00
# 12  tipo_servicio_1  2020-10-31   7315.00
# 13  tipo_servicio_1  2020-11-30   2625.00
# 14  tipo_servicio_1  2020-12-31   5320.00
# 15  tipo_servicio_1  2021-01-31   3115.00
# 16  tipo_servicio_1  2021-02-28    840.00
# 17  tipo_servicio_1  2021-03-31   3815.00
# 18  tipo_servicio_1  2021-04-30   2905.00
# 19  tipo_servicio_1  2021-05-31   5705.00
# 20  tipo_servicio_1  2021-06-30   5572.00
# 21  tipo_servicio_1  2021-07-31   6300.00
# 22  tipo_servicio_1  2021-08-31   5775.00
# 23  tipo_servicio_1  2021-09-30   7084.00
# 24  tipo_servicio_1  2021-10-31   5845.00
# 25  tipo_servicio_1  2021-11-30   7014.00
# 26  tipo_servicio_1  2021-12-31   2065.00
# 27  tipo_servicio_1  2022-01-31     70.00
# 28  tipo_servicio_2  2019-12-31    120.00
# 29  tipo_servicio_3  2017-11-30     35.00
# 30  tipo_servicio_3  2017-12-31      0.00
# 31  tipo_servicio_3  2018-01-31      0.00
# 32  tipo_servicio_3  2018-02-28      0.00
# 33  tipo_servicio_3  2018-03-31      0.00
# 34  tipo_servicio_3  2018-04-30      0.00
# 35  tipo_servicio_3  2018-05-31      0.00
# 36  tipo_servicio_3  2018-06-30      0.00
# 37  tipo_servicio_3  2018-07-31      0.00
# 38  tipo_servicio_3  2018-08-31      0.00
# 39  tipo_servicio_3  2018-09-30      0.00
# 40  tipo_servicio_3  2018-10-31      0.00
# 41  tipo_servicio_3  2018-11-30      0.00
# 42  tipo_servicio_3  2018-12-31      0.00
# 43  tipo_servicio_3  2019-01-31    855.75
# 44  tipo_servicio_3  2019-02-28   1641.50
# 45  tipo_servicio_3  2019-03-31   1650.25
# 46  tipo_servicio_3  2019-04-30   2373.00
# 47  tipo_servicio_3  2019-05-31   3116.75
# 48  tipo_servicio_3  2019-06-30   2535.50
# 49  tipo_servicio_3  2019-07-31   4945.50
# 50  tipo_servicio_3  2019-08-31   4700.50
# 51  tipo_servicio_3  2019-09-30   4882.50
# 52  tipo_servicio_3  2019-10-31   3932.25
# 53  tipo_servicio_3  2019-11-30    252.00
# 54  tipo_servicio_3  2019-12-31    105.00
# 55  tipo_servicio_3  2020-01-31   6384.00
# 56  tipo_servicio_3  2020-02-29   7124.00
# 57  tipo_servicio_3  2020-03-31   1540.00
# 58  tipo_servicio_3  2020-04-30      0.00
# 59  tipo_servicio_3  2020-05-31      0.00
# 60  tipo_servicio_3  2020-06-30     84.00
# 61  tipo_servicio_3  2020-07-31   1064.00
# 62  tipo_servicio_3  2020-08-31   3480.75
# 63  tipo_servicio_3  2020-09-30   2418.00
# 64  tipo_servicio_3  2020-10-31   5139.75
# 65  tipo_servicio_3  2020-11-30   2782.50
# 66  tipo_servicio_3  2020-12-31   7708.75
# 67  tipo_servicio_3  2021-01-31   4599.00
# 68  tipo_servicio_3  2021-02-28   2238.25
# 69  tipo_servicio_3  2021-03-31   7577.50
# 70  tipo_servicio_3  2021-04-30   7105.00
# 71  tipo_servicio_3  2021-05-31   7316.25
# 72  tipo_servicio_3  2021-06-30   5671.25
# 73  tipo_servicio_3  2021-07-31   7393.50
# 74  tipo_servicio_3  2021-08-31   9850.50
# 75  tipo_servicio_3  2021-09-30   9511.00
# 76  tipo_servicio_3  2021-10-31  11233.25
# 77  tipo_servicio_3  2021-11-30  10003.00
# 78  tipo_servicio_3  2021-12-31   3843.00
# 79  tipo_servicio_3  2022-01-31    378.00
# 80  tipo_servicio_4  2017-01-31    436.45
# 81  tipo_servicio_4  2017-02-28    232.20
# 82  tipo_servicio_4  2017-03-31    180.60
# 83  tipo_servicio_4  2017-04-30     86.00
# 84  tipo_servicio_4  2017-05-31     51.60

# %%
ventas_productos_en_tiempo_df = facturacion_mensual_por_producto_df.pivot('fecha_venta','tipo_servicio').fillna(0)

ventas_productos_en_tiempo_df = ventas_productos_en_tiempo_df.reset_index()
ventas_productos_en_tiempo_df = ventas_productos_en_tiempo_df.set_index('fecha_venta')
ventas_productos_en_tiempo_df.columns = ventas_productos_en_tiempo_df.columns.droplevel(0)

ventas_productos_en_tiempo_df
# Out:
# tipo_servicio  tipo_servicio_1  tipo_servicio_2  tipo_servicio_3  \
# fecha_venta
# 2017-01-31                0.00              0.0             0.00
# 2017-02-28                0.00              0.0             0.00
# 2017-03-31                0.00              0.0             0.00
# 2017-04-30                0.00              0.0             0.00
# 2017-05-31                0.00              0.0             0.00
# 2017-11-30                0.00              0.0            35.00
# 2017-12-31                0.00              0.0             0.00
# 2018-01-31                0.00              0.0             0.00
# 2018-02-28                0.00              0.0             0.00
# 2018-03-31                0.00              0.0             0.00
# 2018-04-30                0.00              0.0             0.00
# 2018-05-31                0.00              0.0             0.00
# 2018-06-30                0.00              0.0             0.00
# 2018-07-31                0.00              0.0             0.00
# 2018-08-31                0.00              0.0             0.00
# 2018-09-30                0.00              0.0             0.00
# 2018-10-31                0.00              0.0             0.00
# 2018-11-30                0.00              0.0             0.00
# 2018-12-31                0.00              0.0             0.00
# 2019-01-31                0.00              0.0           855.75
# 2019-02-28                0.00              0.0          1641.50
# 2019-03-31                0.00              0.0          1650.25
# 2019-04-30                0.00              0.0          2373.00
# 2019-05-31                0.00              0.0          3116.75
# 2019-06-30                0.00              0.0          2535.50
# 2019-07-31                0.00              0.0          4945.50
# 2019-08-31                0.00              0.0          4700.50
# 2019-09-30                0.00              0.0          4882.50
# 2019-10-31             1610.00              0.0          3932.25
# 2019-11-30             6475.00              0.0           252.00
# 2019-12-31             8295.00            120.0           105.00
# 2020-01-31            11235.00              0.0          6384.00
# 2020-02-29             9633.75              0.0          7124.00
# 2020-03-31             2555.00              0.0          1540.00
# 2020-04-30                0.00              0.0             0.00
# 2020-05-31                0.00              0.0             0.00
# 2020-06-30             9065.00              0.0            84.00
# 2020-07-31             7525.00              0.0          1064.00
# 2020-08-31             6972.00              0.0          3480.75
# 2020-09-30             6405.00              0.0          2418.00
# 2020-10-31             7315.00              0.0          5139.75
# 2020-11-30             2625.00              0.0          2782.50
# 2020-12-31             5320.00              0.0          7708.75
# 2021-01-31             3115.00              0.0          4599.00
# 2021-02-28              840.00              0.0          2238.25
# 2021-03-31             3815.00              0.0          7577.50
# 2021-04-30             2905.00              0.0          7105.00
# 2021-05-31             5705.00              0.0          7316.25
# 2021-06-30             5572.00              0.0          5671.25
# 2021-07-31             6300.00              0.0          7393.50
# 2021-08-31             5775.00              0.0          9850.50
# 2021-09-30             7084.00              0.0          9511.00
# 2021-10-31             5845.00              0.0         11233.25
# 2021-11-30             7014.00              0.0         10003.00
# 2021-12-31             2065.00              0.0          3843.00
# 2022-01-31               70.00              0.0           378.00
#
# tipo_servicio  tipo_servicio_4
# fecha_venta
# 2017-01-31              436.45
# 2017-02-28              232.20
# 2017-03-31              180.60
# 2017-04-30               86.00
# 2017-05-31               51.60
# 2017-11-30                0.00
# 2017-12-31                0.00
# 2018-01-31                0.00
# 2018-02-28                0.00
# 2018-03-31                0.00
# 2018-04-30                0.00
# 2018-05-31                0.00
# 2018-06-30                0.00
# 2018-07-31                0.00
# 2018-08-31                0.00
# 2018-09-30                0.00
# 2018-10-31                0.00
# 2018-11-30                0.00
# 2018-12-31                0.00
# 2019-01-31                0.00
# 2019-02-28                0.00
# 2019-03-31                0.00
# 2019-04-30                0.00
# 2019-05-31                0.00
# 2019-06-30                0.00
# 2019-07-31                0.00
# 2019-08-31                0.00
# 2019-09-30                0.00
# 2019-10-31                0.00
# 2019-11-30                0.00
# 2019-12-31                0.00
# 2020-01-31                0.00
# 2020-02-29                0.00
# 2020-03-31                0.00
# 2020-04-30                0.00
# 2020-05-31                0.00
# 2020-06-30                0.00
# 2020-07-31                0.00
# 2020-08-31                0.00
# 2020-09-30                0.00
# 2020-10-31                0.00
# 2020-11-30                0.00
# 2020-12-31                0.00
# 2021-01-31                0.00
# 2021-02-28                0.00
# 2021-03-31                0.00
# 2021-04-30                0.00
# 2021-05-31                0.00
# 2021-06-30                0.00
# 2021-07-31                0.00
# 2021-08-31                0.00
# 2021-09-30                0.00
# 2021-10-31                0.00
# 2021-11-30                0.00
# 2021-12-31                0.00
# 2022-01-31                0.00

# %%
ax = pd.DataFrame(ventas_productos_en_tiempo_df.values).plot(
    figsize=(10,7),
    grid=True,
)

ax.set_ylabel('ventas por producto')
ax.set_xlabel('fecha')
ax.set_title('Tendencia de productos a lo largo del tiempo')

ax.legend(ventas_productos_en_tiempo_df.columns, loc='upper left')

plt.xticks(
    range(len(ventas_productos_en_tiempo_df.index)), 
    [x.strftime('%m.%Y') for x in ventas_productos_en_tiempo_df.index], 
    rotation=45
)

plt.show()
